# %% [markdown]
# *Author: C Mitchell*

# %% [markdown]
# # Initializing workflow
#
# Importing modules and setting up the data directories

# %%
import pandas as pd
import os
import re
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
datadir = 'X:/projects/meifsci-seaweed-drones/analysis/data/20211018_Pemaquid2/pemaquid/'

# %% [markdown]
# ## Defining functions

# %%
def groupraw(datadir, filetype):
    # finds all the raw files of filetype from a given 
    # data dir and groups them by filestem
    #
    # inputs: 
    #     datadir = full path to directory with the raw files
    #     filetype = extension of raw filetypes e.g. '.sed'  
    # outputs: a dictionary with the filestem as the key
    #          and the list of corresponding individual 
    #          files as the value
    
    allfiles = os.listdir(datadir)
    
    if filetype == '.sed':
        datafiles = [f for f in allfiles if re.search('.sed',f)]
        ind = [re.search('_[0-9]{5}\.sed',f).start() for f in datafiles]
    elif filetype == '.sig':
        datafiles = [f for f in allfiles if re.search('.sig',f)]
        ind = [re.search('_[0-9]{4}\.sig',f).start() for f in datafiles]
    else: 
        print("unknown file type, expect either '.sed' or '.sig'")
        
    fstem = sorted(set([f[:ii] for f,ii in zip(datafiles,ind)]))
    filegroups = {}
    for fs in fstem:
        filegroups[fs] = [datadir+f for f in datafiles if re.match(fs+'_[0-9]',f)]
    
    return filegroups

# %% [markdown]
# # Processing files
#
# Now we can loop through the files, import the data, and combine it into one data frame.
#
# We have to do this different compared to the spectral library, because we don't want to take the mean of the different leafclip scans, we want to keep them all.

# %%
filegroups = groupraw(datadir,'.sig')

groupkeys = ['leafclip_asco','leafclip_fucus']

data = []
for gkey in groupkeys:
    filelist = filegroups[gkey]
    for ff in filelist:
        fid = re.search('_\d{4}\.sig',ff).group()[1:5]
        data += [pd.read_csv(ff,sep='\s+',skiprows=27,header=None,usecols=[3],names = [gkey+'_'+fid])]

lcdf = pd.concat(data,axis=1)
lcdf['Wvl'] = pd.read_csv(ff,sep='\s+',skiprows=27,header=None,usecols=[0],names = ['Wvl'])
lcdf.set_index('Wvl',inplace = True)

# %%
lcdf
# Out:
#         leafclip_asco_0000  leafclip_asco_0001  leafclip_asco_0002  \
# Wvl
# 339.5                 9.36               12.78                9.94
# 340.9                11.36               13.77               12.40
# 342.4                13.51               11.36                8.84
# 343.9                11.66               10.23                7.95
# 345.3                10.57                9.30                8.26
# ...                    ...                 ...                 ...
# 2508.3                3.86                3.29                1.18
# 2510.4                3.46                3.37                1.44
# 2512.5                3.11                3.52                1.64
# 2514.6                3.42                3.23                1.33
# 2516.8                4.01                3.15                0.94
#
#         leafclip_asco_0003  leafclip_asco_0004  leafclip_asco_0005  \
# Wvl
# 339.5                11.25                7.10               15.94
# 340.9                 9.09                6.89               15.45
# 342.4                 4.17                7.58               14.17
# 343.9                 4.50                9.09               12.75
# 345.3                 2.73                8.26               10.91
# ...                    ...                 ...                 ...
# 2508.3                0.86                1.25                2.59
# 2510.4                1.20                1.52                2.73
# 2512.5                1.23                1.55                2.53
# 2514.6                1.16                1.24                2.32
# 2516.8                1.70                1.36                2.98
#
#         leafclip_asco_0006  leafclip_asco_0007  leafclip_asco_0008  \
# Wvl
# 339.5                 7.10               12.78               11.25
# 340.9                11.02               12.40               10.91
# 342.4                10.10               12.63               10.00
# 343.9                 6.82               11.36                9.00
# 345.3                12.40               11.36                9.55
# ...                    ...                 ...                 ...
# 2508.3                3.29                2.43                1.33
# 2510.4                3.29                2.49                1.20
# 2512.5                3.43                2.37                1.55
# 2514.6                3.40                2.49                1.33
# 2516.8                2.90                2.73                1.45
#
#         leafclip_asco_0009  ...  leafclip_fucus_0041  leafclip_fucus_0042  \
# Wvl                         ...
# 339.5                11.36  ...                 8.08                 6.67
# 340.9                12.40  ...                10.32                 6.38
# 342.4                11.36  ...                 7.13                 5.49
# 343.9                 9.09  ...                 8.82                 4.73
# 345.3                11.36  ...                 8.66                 4.64
# ...                    ...  ...                  ...                  ...
# 2508.3                2.19  ...                 1.33                 1.25
# 2510.4                2.25  ...                 1.28                 1.12
# 2512.5                2.04  ...                 1.63                 1.63
# 2514.6                2.24  ...                 1.92                 1.92
# 2516.8                1.45  ...                 1.46                 1.20
#
#         leafclip_fucus_0043  leafclip_fucus_0044  leafclip_fucus_0045  \
# Wvl
# 339.5                 13.47                 8.08                 9.78
# 340.9                 11.61                 9.03                11.91
# 342.4                 10.70                 9.51                 7.84
# 343.9                 11.02                 8.82                 8.73
# 345.3                 12.99                 8.66                 6.43
# ...                     ...                  ...                  ...
# 2508.3                 3.68                 1.10                 1.80
# 2510.4                 3.77                 1.12                 2.09
# 2512.5                 3.92                 1.39                 1.80
# 2514.6                 3.75                 1.33                 2.00
# 2516.8                 3.86                 1.11                 2.32
#
#         leafclip_fucus_0046  leafclip_fucus_0047  leafclip_fucus_0048  \
# Wvl
# 339.5                  7.11                 7.11                16.00
# 340.9                  5.11                 9.36                16.17
# 342.4                  6.27                 9.41                13.33
# 343.9                  8.00                10.18                11.64
# 345.3                  7.86                10.71                11.43
# ...                     ...                  ...                  ...
# 2508.3                 1.65                 2.27                 2.12
# 2510.4                 1.85                 2.49                 2.41
# 2512.5                 1.39                 2.53                 2.61
# 2514.6                 1.42                 2.25                 2.58
# 2516.8                 2.40                 2.66                 2.57
#
#         leafclip_fucus_0049  leafclip_fucus_0050
# Wvl
# 339.5                  7.11                 8.08
# 340.9                  5.96                 9.03
# 342.4                  4.71                 7.13
# 343.9                  8.00                 7.71
# 345.3                 10.00                 9.74
# ...                     ...                  ...
# 2508.3                 1.41                 0.47
# 2510.4                 1.36                 0.48
# 2512.5                 1.14                 0.65
# 2514.6                 1.08                 0.42
# 2516.8                 0.86                 0.60
#
# [992 rows x 102 columns]

# %% [markdown]
# # Plotting leaf clip data

# %%
regexes = ['asco','fucus']

for rgs in regexes:
    subdf = lcdf.filter(regex = rgs)
    subdf.plot(legend = False)
    plt.title(rgs)
